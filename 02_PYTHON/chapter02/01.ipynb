# %%
x=5000
x

# %%
id(x)

# %%
y = x
y

# %%
x=500
id(x)

# %%
x=600
id(x)

# %%
a=10
id(a)

# %%
a=20
id(a)

# %%
a=10
id(a)

# %%
x=600
id(x)

# %%
number_of_student=100

# %%
type(number_of_student)

# %%
pi = 3.14
type(pi)

# %%
result = True
type(result)

# %%
pi = "원주율"
type(pi)

# %%
user_age=20
product_price=5000

# %%
x=10

# %%
x=10
type(x)
# Out:
# int

# %%
x="Hello"

# %%
type(x)
# Out:
# str

# %%
age=20

# %%
id(age)
# Out:
# 140721291204104

# %%
age=25

# %%
id(age)
# Out:
# 140721291204264

# %%
name="송준호"

# %%
age=30

# %%
message="내 나이는" + str(age) + "살 입니다."

# %%
print(message)
# Out:
# 내 나이는30살 입니다.

# %%
result=10+3.14

# %%
print(result)
# Out:
# 13.14

# %%
int(result)
# Out:
# 13

# %%
user_input="25"

# %%
user_input.isdigit()
# Out:
# True

# %%
if int(user_input).isdigit()=True:
    print("정수 전환 성공")
# Out:
#   Cell In[38], line 1
#     if int(user_input).isdigit()=True:
#        ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
