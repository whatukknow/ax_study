# %% [markdown]
# 1장 3강

# %%
print("everyone")
# Out:
# everyone

# %%
money=5000

# %%
money=money+2000
print(money)
# Out:
# 7000

# %%
money
# Out:
# 7000

# %%
print("world")
# Out:
# world

# %%
print("hello")
# Out:
# hello
