# %% [markdown]
# 1장 3강

# %%
print("everyone")
# Out:
# everyone

# %%
money=5000

# %%
money=money+2000
print(money)
# Out:
# 7000

# %%
money
# Out:
# 7000

# %%
print("world")
# Out:
# world

# %%
print("hello")
# Out:
# hello

# %%
fruit1 = "사과"
fruit2 = "오렌지"
result1 = fruit1 == "사과"
result2 = fruit2 == "오렌지"

result1, result2
# Out:
# (True, True)

# %%
result1 or result2
# Out:
# True

# %%
not (result1 and result2)
# Out:
# False

# %% [markdown]
# 3. 단락 회로 평가 (Short Circuit Evaluation)

# %%
result = True or 10**2 #첫 항의 결과가 True -> 결과가 이미 결정 -> 다음 연산 진행 X
result
# Out:
# True

# %%
result = False or 10 ** 2 # 첫 항의 결과가 False -> 결과 아직 미정 -> 다음 항 체크 (연산)
result
# Out:
# 100

# %%
result = False and 10 ** 2
result
# Out:
# False

# %%
result = True and 10 ** 2
result
# Out:
# 100

# %%
# or 연산을 이용한 기본값(없을때 대체되는 값)
message =""

result = message or "기본 메시지"
result
# Out:
# '기본 메시지'

# %%
# and 연산을 이용한 간단한 조건 처리
height = 165

result = height >= 160 and "크다"
result
# Out:
# '크다'

# %%
num = 1
num += 1
num
# Out:
# 2

# %%
print("name은 프로젝트의 이름을 지정해주는 메타데이터 항목입니다")
print("requires-python은 프로젝트에서 필요한 최소 Python 버전을 지정하는 메타데이터 항목입니다")
# Out:
# name은 프로젝트의 이름을 지정해주는 메타데이터 항목입니다
# requires-python은 프로젝트에서 필요한 최소 Python 버전을 지정하는 메타데이터 항목입니다
