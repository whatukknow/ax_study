# %% [markdown]
# 6장 제 1강

# %%
def add(num1,num2):
    return num1 + num2

def minus(num1,num2):
    return num1 - num2

# %%
import mod1

# %%
mod1.add(10,20)
# Out:
# 30

# %%
mod1.add(10,20)
# Out:
# 30

# %%
from mod1 import add, minus VERSION
# Out:
#   Cell In[26], line 1
#     from mod1 import add, minus VERSION
#                                 ^
# SyntaxError: invalid syntax

# %%
add(10,20)

version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 add(10,20)
#       2
# ----> 3 version
#
# NameError: name 'version' is not defined

# %%
from chapter06.sub import mod3
from utils import mod2

# %%
mod2.Multiply(10,20)
# Out:
# 200

# %%
from utils.mod2 import Multiply
Multiply(10,20)
# Out:
# 200

# %%
from utils.sub.mod3 import print_version
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from utils.sub.mod3 import print_version
#
# ModuleNotFoundError: No module named 'utils.sub'

# %%
import mod1

# %%
from game import lol
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from game import lol
#
# File ~\ax_study\02_PYTHON\chapter06\game\__init__.py:1
# ----> 1 import lol
#       3 print("공통 초기화 작업을 수행합니다....")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
import game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import game
#
# File ~\ax_study\02_PYTHON\chapter06\game\__init__.py:1
# ----> 1 import lol
#       3 print("공통 초기화 작업을 수행합니다....")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
game.common_func()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 game.common_func()
#
# NameError: name 'game' is not defined

# %%
from game import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from game import *
#
# File ~\ax_study\02_PYTHON\chapter06\game\__init__.py:1
# ----> 1 import lol
#       3 print("공통 초기화 작업을 수행합니다....")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
from chapter06.game import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from chapter06.game import *
#
# ModuleNotFoundError: No module named 'chapter06'

# %%
from game import *

lol
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from game import *
#       2
#       3 lol
#
# File ~\ax_study\02_PYTHON\chapter06\game\__init__.py:1
# ----> 1 import lol
#       3 print("공통 초기화 작업을 수행합니다....")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
from lol import LOL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from lol import LOL
#
# ModuleNotFoundError: No module named 'lol'

# %%
print("공통 초기화 작업을 수행합니다....")
# Out:
# 공통 초기화 작업을 수행합니다....

# %%
import mod1 as m


m.add(10,20)
# Out:
# 30

# %%
from mod1 import add, minus, VERSION

# %%
import random

dice_number=random.randint(1,6)

print(f"주사위 결과:{dice_number}" )
# Out:
# 주사위 결과:3

# %%
import datetime

today_time=datetime.datetime.now()

today_date=today_time.strftime('%y-%m-%d')

print(f'오늘 날짜는 {today_date}')
# Out:
# 오늘 날짜는 26-08-14

# %%
import datetime as d

now=d.datetime.now()

current_time=now.strftime('%H:%M:%S')

print(f'오늘 시간은 {current_time}')
# Out:
# 오늘 시간은 16:19:19
